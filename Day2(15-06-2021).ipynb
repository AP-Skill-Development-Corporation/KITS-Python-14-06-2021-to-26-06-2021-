# %%
- markdown mode----->theory
- code mode--------->programs

# %%
b-below cell
a- above cell
m- markdown mode

# %%
In []---->code
empty--->markdown mode

# %% [markdown]
# #markdown mode--->theory

# %%
#codemode--->programs

# %%
run----->shift+enter

# %% [markdown]
# # python
# ## python
# ### python
# #### python
# ##### python
# ###### python
# ####### python

# %% [markdown]
# - python
# - **bold**
# - *italic*
# - ***bolditalic***

# %% [markdown]
# - Normal
#     - sublist1
#     - sublist2
#         - subsublist1
#         - subsublist2
#             - subsubsublist1

# %% [markdown]
# - 1.orderedlist1
# - 2.ordered list2
#     - 1.ordredsublist1
#     - 2.ordredsublist2

# %% [markdown]
# [amazon](https://www.amazon.com/)

# %%
cntrl+c--->copy
cntrl+v---->paste

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# python basics
- comments in python
- variables
- keywords
- datatypes
- type conversions/type casting
- dynamic input/user input

# %%
# comments:
- comment is not a part of the program,but it makes the program readable,which is not executed
- single line comments--->#
- multi line comments---->"""   """

# %%
# single line comment
"""
multi
line
comments
"""
print("hii everyone!")
# Out:
# hii everyone!

# %%
print("python workshop")
print('python workshop')
# Out:
# python workshop
# python workshop

# %%
- in python " ",'' are used as same

# %%
print("python's workshop")
print('python"s workshop')
#print('python's workshop')
#print("python"s workshop")
# Out:
# python's workshop
# python"s workshop

# %%
" '"---->possible
"""---->not possible
'"'----->possible
'''----->not possible

# %% [markdown]
# #variables:
# - variable is a name which is used to refer memory location it holds values
# ex:a=10
#     a---->variable
#     10--->value
# - rules to create variables
# - we don't need to specify the type of variable in python...becoz it is a type infer language.
# - variable names can be a group of both letters and digits,but they have to begin with a letter or an underscore and we can't use special charcters in varible names.
# - keywords cannot be used as variable names

# %%
a=10.78
print("a")
print(a)
print(type(a))
# Out:
# a
# 10.78
# <class 'float'>

# %%
py=56  #we can start variable name with alphabetbet and underscore
print(p)
# Out:
# 56

# %%
_p=56
print(_p)
# Out:
# 56

# %%
4p=56  #we can't start variable name with number
print(4p)
# Out:
#   File "<ipython-input-23-3a3789b017d6>", line 1
#     4p=56  #we can't start variable name with number
#      ^
# SyntaxError: invalid syntax

# %%
@p=56   #invariables we can't use special charcters
print(@p)
# Out:
#   File "<ipython-input-25-d94819ec4f4f>", line 1
#     @p=56
#       ^
# SyntaxError: invalid syntax

# %%
_p123gfb=56
print(_p123gfb)
# Out:
# 56

# %%
p_123$89=56
print(p_123$89)
# Out:
#   File "<ipython-input-27-c917b277977e>", line 1
#     p_123$89=56
#          ^
# SyntaxError: invalid syntax

# %%
p_123fgfg=90
print(p_123fgfg)
# Out:
# 90

# %%
#keywords:
- keywords are the reserved words in python
- we cannot use keywords as variable name,function name...etc

# %%
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
False=78  #we can't use keyword as a variable name
print(False)
# Out:
#   File "<ipython-input-31-791613ffb0c0>", line 1
#     False=78
#             ^
# SyntaxError: can't assign to keyword

# %%
# datatypes:
- type of data
- int
- float
- str (string)

# %%
n=56
print(n)
print(type(n))
# Out:
# 56
# <class 'int'>

# %%
s="python"
print(s)
print(type(s))
# Out:
# python
# <class 'str'>

# %%
f=89.78
print(f)
print(type(f))
# Out:
# 89.78
# <class 'float'>

# %%
a=89
b="python"
c=78.90
print(a)
print(b)
print(c)
# Out:
# 89
# python
# 78.9

# %%
a=89
b="python"
c=78.90
print(a,b,c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 89 python 78.9
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
a=89
b="python"  #no need use ; in python
c=78.90
print(a,b,c)
print(type(a))
print(type(b))
print(type(c))

# %%
a=89
b="python"  
c=78.90
print(a,b,c)
print(type(a,b,c))
# Out:
# 89 python 78.9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-eaf4bda62822> in <module>
#       3 c=78.90
#       4 print(a,b,c)
# ----> 5 print(type(a,b,c))
#
# TypeError: type.__new__() argument 1 must be str, not int

# %%
a=89
b="python"  
c=78.90
print(a,b,c)
print(type(a),type(b),type(c))
# Out:
# 89 python 78.9
# <class 'int'> <class 'str'> <class 'float'>

# %%
a=89,b="python",c=78.90
print(a,b,c)
print(type(a),type(b),type(c))
# Out:
#   File "<ipython-input-40-790690ea28b0>", line 1
#     a=89,b="python",c=78.90
#      ^
# SyntaxError: can't assign to literal

# %%
a,b,c=89,"python",78.90
print(a,b,c)
print(type(a),type(b),type(c))
# Out:
# 89 python 78.9
# <class 'int'> <class 'str'> <class 'float'>

# %%
a,b,c=10,10,10
print(a,b,c)
print(type(a),type(b),type(c))
# Out:
# 10 10 10
# <class 'int'> <class 'int'> <class 'int'>

# %%
a,b,c=10
print(a,b,c)
print(type(a),type(b),type(c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-0e586f60fe78> in <module>
# ----> 1 a,b,c=10
#       2 print(a,b,c)
#       3 print(type(a),type(b),type(c))
#
# TypeError: cannot unpack non-iterable int object

# %%
a=b=c=10
print(a,b,c)
print(type(a),type(b),type(c))
# Out:
# 10 10 10
# <class 'int'> <class 'int'> <class 'int'>

# %%
a=10
print(a)
# Out:
# 10

# %%
a=50
print(a)
# Out:
# 50

# %%
a
# Out:
# 50

# %%
a=a+1
print(a)
# Out:
# 51

# %%
n="67"
print(n,type(n))
# Out:
# 67 <class 'str'>

# %%
n=n+1
print(n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-54860ca56cdc> in <module>
# ----> 1 n=n+1
#       2 print(n)
#
# TypeError: can only concatenate str (not "int") to str

# %%
int+str---->not possible
int+int---->possible
int+float--->possible


str+int--->not possible
str+str--->possible
str+float--->not possible

float+int--->possible
float+str--->not possible
float+float-->possible

# %%
print("67"+"1")
print(67+1)
# Out:
# 671
# 68

# %%
"67"+1
"67"--->67
1---->"1"

# %%
#type casting:
int----->int(variable_name)
float---->float(variable_name)
str----->str(varible_name)

# %%
#type conversion:
#str--->int
n="67"
print(n,type(n))
n1=int(n)
print(n1,type(n1))
# Out:
# 67 <class 'str'>
# 67 <class 'int'>

# %%
print(n1+1)
# Out:
# 68

# %%
# int--->str
n="67"
n1=1
print(n+str(n1))
# Out:
# 671

# %%
#int--->float
s=78
print(s,type(s))
s1=float(s)
print(s1,type(s1))
# Out:
# 78 <class 'int'>
# 78.0 <class 'float'>

# %%
s="python"
s1=int(s)
print(s1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-5c9b08911d8a> in <module>
#       1 s="python"
# ----> 2 s1=int(s)
#       3 print(s1)
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
"67"--->int,float
"python"--->we can't convert
67---->str,float
78.90---->str,int

# %%
#dynamic input:(user input)
str----->input() or str(input())
int----->int(input())
float---->float(input())

# %%
a=input("enter a number: ")
print(a,type(a))
# Out:
# enter a number: 67
# 67 <class 'str'>

# %%
a=input()
print(a,type(a))
# Out:
# python
# python <class 'str'>

# %%
a=str(input())
print(a,type(a))
# Out:
# 67.89
# 67.89 <class 'str'>

# %%
dynamic str----->"python","56","67.45"

# %%
n=int(input())
print(n,type(n))
# Out:
# 45
# 45 <class 'int'>

# %%
f=float(input())
print(f,type(f))
# Out:
# 78.6
# 78.6 <class 'float'>

# %%
input()---->str,int,float
int(input())--->only int
float(input())--->int,float

# %%
#str-->int
s=input()
print(s,type(s))
s1=int(s)
print(s1,type(s1))
# Out:
# 67
# 67 <class 'str'>
# 67 <class 'int'>

# %%
#int-->float
n=int(input())
print(n,type(n))
n1=float(n)
print(n1,type(n1))
# Out:
# 45
# 45 <class 'int'>
# 45.0 <class 'float'>
