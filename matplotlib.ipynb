# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y = [10,5,8,4,2]
plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
z=[9,4,21,13]
plt.hist(z)
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.title("scattor plot")
plt.xlabel("x value")
plt.ylabel("y value")
plt.scatter(x,y)
plt.show()
print(x,y)
# Out:
# [1, 2, 3, 4, 5] [10, 5, 8, 4, 2]

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16]) # x,y
plt.axis([0, 6, 0, 20])
plt.show()

# %%
year = [1972, 1982, 1992, 2002, 2012]
e_india = [100.6, 158.61, 305.54, 394.96, 724.79]
e_bangladesh = [10.5, 25.21, 58.65, 119.27, 274.87]
plt.plot(year, e_india, color ='orange',linestyle="--",label ='India')
  
plt.plot(year, e_bangladesh, color ='g',linestyle="dashed",label ='Bangladesh')
plt.xlabel('Years')
plt.ylabel('Power consumption in kWh')
plt.title('Electricity consumption per capital of India and Bangladesh')
plt.legend()
plt.show()
